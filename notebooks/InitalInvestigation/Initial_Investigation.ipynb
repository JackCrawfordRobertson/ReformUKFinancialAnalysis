# %%
import pandas as pd

# Assuming there's a data file in the 'data' directory
data = pd.read_csv('../data/Reform_UK_results.csv')
print(data.head())
print(data.columns)
# Out:
#        ECRef              RegulatedEntityName RegulatedEntityType  \
# 0   C0578740                       Alba Party     Political Party
# 1   C0578707                     Labour Party     Political Party
# 2   C0578719                        Reform UK     Political Party
# 3   C0578721                        Reform UK     Political Party
# 4  NC0578738  Conservative and Unionist Party     Political Party
#
#          Value  AcceptedDate AccountingUnitName  \
# 0   £36,304.56           NaN      Central Party
# 1   £20,000.00           NaN      Central Party
# 2   £21,000.00           NaN      Central Party
# 3  £250,000.00           NaN      Central Party
# 4   £25,000.00           NaN      Central Party
#
#                                    DonorName  AccountingUnitsAsCentralParty  \
# 0                       ELECTORAL COMMISSION                          False
# 1  Medical and Professional Services Limited                          False
# ...

# %%
# Checking for the unique values in the 'RegulatedEntityName' column to filter data specific to Reform UK
unique_entities = data['RegulatedEntityName'].unique()
unique_entities
# Out:
# array(['Alba Party', 'Labour Party', 'Reform UK',
#        'Conservative and Unionist Party', 'Green Party',
#        'Liberal Democrats', 'Co-operative Party'], dtype=object)

# %%
# Filtering the data to only include entries related to Reform UK
reform_uk_only = data[data['RegulatedEntityName'] == 'Reform UK']

# Display the filtered data to understand its structure and content
reform_uk_only.head()
# Out:
#        ECRef RegulatedEntityName RegulatedEntityType        Value  \
# 2   C0578719           Reform UK     Political Party   £21,000.00
# 3   C0578721           Reform UK     Political Party  £250,000.00
# 9   C0578720           Reform UK     Political Party   £25,000.00
# 12  C0578718           Reform UK     Political Party  £100,000.00
# 17  C0578717           Reform UK     Political Party   £21,000.00
#
#     AcceptedDate AccountingUnitName                       DonorName  \
# 2            NaN      Central Party          Mr Simon William Smith
# 3            NaN      Central Party  Britain Means Business Limited
# 9            NaN      Central Party                 Mr philip Hulme
# 12           NaN      Central Party   Mr David George Plumer Lilley
# 17           NaN      Central Party          Mr Simon William Smith
#
#     AccountingUnitsAsCentralParty  IsSponsorship DonorStatus  ...  \
# 2                           False          False  Individual  ...
# ...

# %%
# Cleaning the 'Value' column to convert it to numeric
reform_uk_only['Value'] = reform_uk_only['Value'].replace('[\£,]', '', regex=True).astype(float)

# Verifying the conversion
reform_uk_only.head()
# Out:
# /var/folders/h5/ydl1chhd0nj3dng49d4f7xnc0000gn/T/ipykernel_51675/3326647184.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reform_uk_only['Value'] = reform_uk_only['Value'].replace('[\£,]', '', regex=True).astype(float)
#        ECRef RegulatedEntityName RegulatedEntityType     Value  AcceptedDate  \
# 2   C0578719           Reform UK     Political Party   21000.0           NaN
# 3   C0578721           Reform UK     Political Party  250000.0           NaN
# 9   C0578720           Reform UK     Political Party   25000.0           NaN
# 12  C0578718           Reform UK     Political Party  100000.0           NaN
# 17  C0578717           Reform UK     Political Party   21000.0           NaN
#
# ...

# %%
# Chart 1: Total donations by top 10 donors
plt.figure(figsize=(10, 6))
plt.barh(top_10_donors['DonorName'], top_10_donors['Value'], color='skyblue')
plt.title('Top 10 Donors to Reform UK')
plt.xlabel('Donation Amount (£)')
plt.gca().invert_yaxis()
plt.show()

# %%
# Chart 2: Distribution of donation amounts
plt.figure(figsize=(10, 6))
plt.hist(reform_uk_only['Value'], bins=20, color='lightgreen')
plt.title('Distribution of Donation Amounts to Reform UK')
plt.xlabel('Donation Amount (£)')
plt.ylabel('Frequency')
plt.show()

# %%
# It appears that the 'donor_type_summary' variable might not be defined in this cell's context.
# Let's redefine it and then generate the pie chart again.

# Redefining donor_type_summary
donor_type_summary = reform_uk_only.groupby('DonorStatus')['Value'].sum().reset_index()

# Chart 3: Total donations by donor type
plt.figure(figsize=(10, 6))
plt.pie(donor_type_summary['Value'], labels=donor_type_summary['DonorStatus'], autopct='%1.1f%%', colors=['gold', 'lightcoral', 'lightskyblue'])
plt.title('Total Donations by Donor Type to Reform UK')
plt.show()
